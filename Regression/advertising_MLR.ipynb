# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.shape
# Out:
# (200, 4)

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
plt.scatter(df['TV'],y)
plt.grid()

# %%
plt.scatter(df['Radio'],y,color='g')
plt.grid()

# %%
plt.scatter(df['Newspaper'],y,color='c')
plt.grid()

# %%
#seaborn
import seaborn as sns
sns.regplot(x=df['TV'],y=y,color='g')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.regplot(x=df['Radio'],y=y,color='r')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.regplot(x=df['Newspaper'],y=y,color='y')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
#         TV  Radio  Newspaper
# 116  139.2   14.3       25.6
# 67   139.3   14.5       10.2
# 78     5.4   29.9        9.4
# 42   293.6   27.7        1.8
# 17   281.4   39.6       55.8
# ..     ...    ...        ...
# 133  219.8   33.5       45.1
# 137  273.7   28.9       59.7
# 72    26.8   33.0       19.3
# 140   73.4   17.0       12.9
# 37    74.7   49.4       45.7
#
# [140 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 58   210.8   49.6       37.7
# 40   202.5   22.3       31.6
# 34    95.7    1.4        7.4
# 102  280.2   10.1       21.4
# 184  253.8   21.3       30.0
# 198  283.6   42.0       66.2
# 95   163.3   31.6       52.9
# 4    180.8   10.8       58.4
# 29    70.6   16.0       40.8
# 168  215.4   23.6       57.6
# 171  164.5   20.9       47.4
# 18    69.2   20.5       18.3
# 11   214.7   24.0        4.0
# 89   109.8   47.8       51.4
# 110  225.8    8.2       56.5
# 118  125.7   36.9       79.2
# 159  131.7   18.4       34.6
# 35   290.7    4.1        8.5
# 136   25.6   39.0        9.3
# 59   210.7   29.5        9.3
# 51   100.4    9.6        3.6
# 16    67.8   36.6      114.0
# 44    25.1   25.7       43.3
# 94   107.4   14.0       10.9
# 31   112.9   17.4       38.6
# 162  188.4   18.1       25.6
# 38    43.1   26.7       35.1
# 28   248.8   27.1       22.9
# 193  166.8   42.0        3.6
# 27   240.1   16.7       22.9
# 47   239.9   41.5       18.5
# 165  234.5    3.4       84.8
# 194  149.7   35.6        6.0
# 177  170.2    7.8       35.2
# 176  248.4   30.2       20.3
# 97   184.9   21.0       22.0
# 174  222.4    3.4       13.1
# 73   129.4    5.7       31.3
# 69   216.8   43.9       27.2
# 172   19.6   20.1       17.0
# 108   13.1    0.4       25.6
# 107   90.4    0.3       23.2
# 189   18.7   12.1       23.4
# 14   204.1   32.9       46.0
# 56     7.3   28.1       41.4
# 19   147.3   23.9       19.1
# 114   78.2   46.8       34.5
# 39   228.0   37.7       32.0
# 185  205.0   45.1       19.6
# 124  229.5   32.3       74.2
# 98   289.7   42.3       51.2
# 123  123.1   34.6       12.4
# 119   19.4   16.0       22.3
# 53   182.6   46.2       58.7
# 33   265.6   20.0        0.3
# 179  165.6   10.0       17.6
# 181  218.5    5.4       27.4
# 106   25.0   11.0       29.7
# 199  232.1    8.6        8.7
# 138   43.0   25.9       20.5

# %%
y_train
# Out:
# 116    12.2
# 67     13.4
# 78      5.3
# 42     20.7
# 17     24.4
#        ...
# 133    19.6
# 137    20.8
# 72      8.8
# 140    10.9
# 37     14.7
# Name: Sales, Length: 140, dtype: float64

# %%
y_test
# Out:
# 58     23.8
# 40     16.6
# 34     11.9
# 102    19.8
# 184    17.6
# 198    25.5
# 95     16.9
# 4      17.9
# 29     10.5
# 168    17.1
# 171    17.5
# 18     11.3
# 11     17.4
# 89     16.7
# 110    18.4
# 118    15.9
# 159    12.9
# 35     17.8
# 136     9.5
# 59     18.4
# 51     10.7
# 16     12.5
# 44      8.5
# 94     11.5
# 31     11.9
# 162    19.9
# 38     10.1
# 28     18.9
# 193    19.6
# 27     20.9
# 47     23.2
# 165    16.9
# 194    17.3
# 177    16.7
# 176    20.2
# 97     20.5
# 174    16.5
# 73     11.0
# 69     22.3
# 172     7.6
# 108     5.3
# 107    12.0
# 189     6.7
# 14     19.0
# 56      5.5
# 19     14.6
# 114    14.6
# 39     21.5
# 185    22.6
# 124    19.7
# 98     25.4
# 123    15.2
# 119     6.6
# 53     21.2
# 33     17.4
# 179    17.6
# 181    17.2
# 106     7.2
# 199    18.4
# 138     9.6
# Name: Sales, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([21.28816103, 18.04213212, 10.0595901 , 21.08224067, 20.76476044,
#        24.47187353, 16.80643646, 15.62885738, 10.12479884, 18.84601896,
#        15.78389695, 10.54297035, 18.92928707, 15.52557996, 17.8412711 ,
#        15.24120343, 13.74212833, 21.0643733 , 10.05392699, 19.26500889,
#        11.16451173, 11.97211832,  8.61179009, 11.98972141, 12.59914023,
#        16.8447954 ,  9.7170889 , 21.09489946, 18.13942474, 19.55008709,
#        22.08796224, 17.78527998, 16.53883452, 14.77303861, 21.39458945,
#        16.95491635, 17.22755002, 12.31866943, 21.04982199,  7.77473926,
#         5.38467516,  9.63139004,  6.89549204, 19.19507436,  7.88125192,
#        15.18766673, 13.70978421, 21.0232936 , 20.5350058 , 20.48867548,
#        24.86087902, 14.96304281,  7.33545571, 19.35630325, 21.32554066,
#        14.7719757 , 17.19642519,  7.11988693, 18.30096543,  9.65158222])

# %%
print(model.predict([[20,12,11]]))
# Out:
# [6.97546024]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Slope is",list(zip(x,model.coef_)))
# Out:
# Slope is [('TV', np.float64(0.055023917673153074)), ('Radio', np.float64(0.10251002697521278)), ('Newspaper', np.float64(-0.0015071052925105669))]

# %%
print("constant is",model.intercept_)
# Out:
# constant is 4.661439720130817

# %%
df1=pd.DataFrame({"Actual_Value":y_test,"Predicted_Value":y_pred,"Difference":y_test-y_pred})
df1
# Out:
#      Actual_Value  Predicted_Value  Difference
# 58           23.8        21.288161    2.511839
# 40           16.6        18.042132   -1.442132
# 34           11.9        10.059590    1.840410
# 102          19.8        21.082241   -1.282241
# 184          17.6        20.764760   -3.164760
# 198          25.5        24.471874    1.028126
# 95           16.9        16.806436    0.093564
# 4            17.9        15.628857    2.271143
# 29           10.5        10.124799    0.375201
# 168          17.1        18.846019   -1.746019
# 171          17.5        15.783897    1.716103
# 18           11.3        10.542970    0.757030
# 11           17.4        18.929287   -1.529287
# 89           16.7        15.525580    1.174420
# 110          18.4        17.841271    0.558729
# 118          15.9        15.241203    0.658797
# 159          12.9        13.742128   -0.842128
# 35           17.8        21.064373   -3.264373
# 136           9.5        10.053927   -0.553927
# 59           18.4        19.265009   -0.865009
# 51           10.7        11.164512   -0.464512
# 16           12.5        11.972118    0.527882
# 44            8.5         8.611790   -0.111790
# 94           11.5        11.989721   -0.489721
# 31           11.9        12.599140   -0.699140
# 162          19.9        16.844795    3.055205
# 38           10.1         9.717089    0.382911
# 28           18.9        21.094899   -2.194899
# 193          19.6        18.139425    1.460575
# 27           20.9        19.550087    1.349913
# 47           23.2        22.087962    1.112038
# 165          16.9        17.785280   -0.885280
# 194          17.3        16.538835    0.761165
# 177          16.7        14.773039    1.926961
# 176          20.2        21.394589   -1.194589
# 97           20.5        16.954916    3.545084
# 174          16.5        17.227550   -0.727550
# 73           11.0        12.318669   -1.318669
# 69           22.3        21.049822    1.250178
# 172           7.6         7.774739   -0.174739
# 108           5.3         5.384675   -0.084675
# 107          12.0         9.631390    2.368610
# 189           6.7         6.895492   -0.195492
# 14           19.0        19.195074   -0.195074
# 56            5.5         7.881252   -2.381252
# 19           14.6        15.187667   -0.587667
# 114          14.6        13.709784    0.890216
# 39           21.5        21.023294    0.476706
# 185          22.6        20.535006    2.064994
# 124          19.7        20.488675   -0.788675
# 98           25.4        24.860879    0.539121
# 123          15.2        14.963043    0.236957
# 119           6.6         7.335456   -0.735456
# 53           21.2        19.356303    1.843697
# 33           17.4        21.325541   -3.925541
# 179          17.6        14.771976    2.828024
# 181          17.2        17.196425    0.003575
# 106           7.2         7.119887    0.080113
# 199          18.4        18.300965    0.099035
# 138           9.6         9.651582   -0.051582

# %%
from sklearn.metrics import mean_absolute_error
MAE=mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 1.1947417134056737

# %%
from sklearn.metrics import mean_absolute_percentage_error
MAPE=mean_absolute_percentage_error(y_test,y_pred)
MAPE
# Out:
# 0.07695080788726728

# %%
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 2.370659971225657

# %%
from sklearn.metrics import root_mean_squared_error
RMSE=root_mean_squared_error(y_test,y_pred)
RMSE
# Out:
# 1.5396947656031235

# %%
from sklearn.metrics import r2_score
R2_Score=r2_score(y_test,y_pred)
R2_Score
# Out:
# 0.9071151423684273
